# %% [markdown]
# # Long Names, Short Names
# > How long is long? How short is short?

# %% [markdown]
# ## Description
#
# This notebook was created to look at the length of location names,
# since they can take up a lot of space and it influences/affects how
# the information is displayed on a web site. The ultimate goal is to
# seeing what can be done to shorten them.
#
# NOTE: Based on this analysis, the name of a Location is stored as two
# attributes, 'name' for the processed/shortened name and 'original' for
# the name loaded from the API. When a Location is added Django's pre-save
# signal is used to clean the original name and save it in the 'name' attribute.

# %%
from django.db import connection
from django.db.models.functions import Length

from IPython.display import display, HTML

import matplotlib.pyplot as plt
import tabulate

from ebird.api.data.models import Location

# %%
# Find the twenty shortest names
locations = Location.objects.annotate(length=Length("original")).order_by("length")[:20]
names = [location.original for location in locations]

print("\n".join(names))
# Out:
# H
# g
# P
# 🌊
# Cx
# 8F
# 7D
# 9H
# 9D
# 9F
# 5K
# T3
# 6G
# 2M
# 9G
# P1
# 9J
# 9I
# 5J
# 8E

# %%
# Find the twenty longest names
locations = Location.objects.annotate(length=Length('original')).order_by("-length")[:20]
names = [location.original for location in locations]
formatted = "<small>%s</small>" % "<br>".join(names)
display(HTML(formatted))
# Out:
# <small>2a Rua da Boavista, União das freguesias de Alandroal (Nossa Senhora da Conceição), São Brás dos Matos (Mina do Bugalho) e Juromenha (Nossa Senhora do Loreto), Distrito de Évora, PT (38,738, -7,238)<br>N373, União das freguesias de Alandroal (Nossa Senhora da Conceição), São Brás dos Matos (Mina do Bugalho) e Juromenha (Nossa Senhora do Loreto), Distrito de Évora, PT (38,742, -7,245)<br>N373, União das freguesias de Alandroal (Nossa Senhora da Conceição), São Brás dos Matos (Mina do Bugalho) e Juromenha (Nossa Senhora do Loreto), Distrito de Évora, PT (38,687, -7,434)<br>N255, União das freguesias de Alandroal (Nossa Senhora da Conceição), São Brás dos Matos (Mina do Bugalho) e Juromenha (Nossa Senhora do Loreto), Distrito de Évora, PT (38,638, -7,398)<br>Mata densa e desenvolvida de Salix, area alagada, dormitório e criação, Sta. Marinha. 72 Rua Senhor de Matosinhos, Vila Nova de Gaia, Porto, PT (41,126, -8,625)<br>Autoestrada das Beiras Litoral e Alta, União das freguesias de Celorico (São Pedro e Santa Maria) e Vila Boa do Mondego, Distrito da Guarda, PT (40,634, -7,441)<br>Autoestrada do Interior Norte, Vidago (União das freguesias de Vidago, Arcossó, Selhariz e Vilarinho das Paranheiras), Vila Real, PT (41,661, -7,577)<br>Autoestrada do Alentejo, União das freguesias de Nossa Senhora da Vila, Nossa Senhora do Bispo e Silveiras, Distrito de Évora, PT (38,619, -8,083)<br>Itinerário Complementar 5 (Charca Parque Fotovoltaico), União das freguesias de Brunhozinho, Castanheira e Sanhoane, Bragança, PT (41,358, -6,569)<br>Autoestrada do Alentejo, União das freguesias de Nossa Senhora da Vila, Nossa Senhora do Bispo e Silveiras, Distrito de Évora, PT (38,669, -8,178)<br>Autoestrada do Alentejo, União das freguesias de Nossa Senhora da Vila, Nossa Senhora do Bispo e Silveiras, Distrito de Évora, PT (38.635, -8.302)<br>Autoestrada do Alentejo, União das freguesias de Nossa Senhora da Vila, Nossa Senhora do Bispo e Silveiras, Distrito de Évora, PT (38.644, -8.369)<br>Autoestrada do Alentejo, União das freguesias de Nossa Senhora da Vila, Nossa Senhora do Bispo e Silveiras, Distrito de Évora, PT (38,635, -8,307)<br>Autoestrada do Alentejo, União das freguesias de Nossa Senhora da Vila, Nossa Senhora do Bispo e Silveiras, Distrito de Évora, PT (38.657, -8.167)<br>Autoestrada do Alentejo, União das freguesias de Nossa Senhora da Vila, Nossa Senhora do Bispo e Silveiras, Distrito de Évora, PT (38,67, -8,226)<br>Autoestrada do Alentejo, União das freguesias de Nossa Senhora da Vila, Nossa Senhora do Bispo e Silveiras, Distrito de Évora, PT (38,64, -8,354)<br>Autoestrada do Alentejo, União das freguesias de Nossa Senhora da Vila, Nossa Senhora do Bispo e Silveiras, Distrito de Évora, PT (38,65, -8,16)<br>2 Rua de Santa Maria, União das freguesias de Alcácer do Sal (Santa Maria do Castelo e Santiago) e Santa Susana, Setúbal, PT (38,294, -8,534)<br>Estrada Nacional 2, União das freguesias de Nossa Senhora da Vila, Nossa Senhora do Bispo e Silveiras, Distrito de Évora, PT (38,754, -8,195)<br>Autoestrada do Sul, União das freguesias de Alcácer do Sal (Santa Maria do Castelo e Santiago) e Santa Susana, Setúbal, PT (38,517, -8,587)</small>

# %%
# What is the distribution of the name lengths?
with connection.cursor() as cursor:
    cursor.execute(
        "select count(*), ((length(original) - 1) / 5)::int as quantile from data_location group by quantile"
    )
    result = sorted(cursor.fetchall(), key=lambda t: t[1])

data: list[int] = []
labels: list[str] = []

for count, index in result:
    start = index * 5 + 1
    end = start + 4
    data.append(count)
    labels.append(end)

fig, ax = plt.subplots()
fig.set_figwidth(15)
ax.bar(labels, data, width=4)
ax.set_xlabel("Name length ranges, e.g. 1-5, 6-10, etc.")
ax.set_ylabel("Number of locations")
ax.set_title('Distribution of location name lengths')
plt.show();

# %%
# Show the distribution in a table.

total = Location.objects.all().count()

labels = ["<=20", "21-40", "41-60", "61-80", "81-100", "101-120", ">120"]

values = [
    Location.objects.annotate(length=Length('original')).filter(length__lte=20).count(),
    Location.objects.annotate(length=Length('original')).filter(length__gt=20, length__lte=40).count(),
    Location.objects.annotate(length=Length('original')).filter(length__gt=40, length__lte=60).count(),
    Location.objects.annotate(length=Length('original')).filter(length__gt=60, length__lte=80).count(),
    Location.objects.annotate(length=Length('original')).filter(length__gt=80, length__lte=100).count(),
    Location.objects.annotate(length=Length('original')).filter(length__gt=100, length__lte=120).count(),
    Location.objects.annotate(length=Length('original')).filter(length__gt=120).count()
]

percentages = [round(value / total * 100, 1) for value in values]

data = zip(labels, values, percentages)

table = tabulate.tabulate(data, headers=["Length", "n", "%"], tablefmt='html')
table
