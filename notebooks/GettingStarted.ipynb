# %%
"""
Getting Started

This notebook show you how to:

1. Create a database and load observations from cvs file containing
   records from the eBird Basic Dataset v1.14

2. Create a database and load observations from the eBird API v2.0

For your convenience, there is a settings file, "ebird/settings.py"
which contains default connection strings used by sqlAlchemy to create
and access the databases in the 'data/databases' directory. You can
replace this will any path you choose.

IMPORTANT: Add the root directory of the project so the environment
variables in the .env file can be loaded. You must add this as the
first cell in any notebook you create.
"""
import os

from dotenv import load_dotenv
from sqlalchemy import create_engine

from main import settings
from main.db import models, loaders

# Load the environment variables
load_dotenv(settings.DOTENV_FILE)
# Out:
# True

# %%
# Create a database and load eBird Basic Dataset observations.
engine = create_engine(settings.EBD_DATABASE_URL)
models.Base.metadata.create_all(engine)

# %%
# Load the records from a csv file.
loader = loaders.EBDLoader(settings.EBD_DATABASE_URL)
loader.load(os.path.join(settings.DATA_DIR, "downloads", "ebd.csv"))
# Out:
# Loading eBird Basic Dataset from /home/stuart/Development/ebird-notebooks/data/downloads/ebd.csv
# .......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Successfully loaded eBird Basic Dataset
# 0 records added
# 0 records updated
# 1399 records unchanged
# 1399 records in total

# %%
# Create a database and load observations using the eBird API.
# The assumption is that the database.
engine = create_engine(settings.API_DATABASE_URL)
models.Base.metadata.create_all(engine)

# %%
# You will need to sign up for a key to access the eBird API.
# https://ebird.org/api/keygen
api_key = os.getenv("EBIRD_API_KEY")
# The region for which to load observations for. This can be any country,
# subnational1, or subnational2 code.
region = os.getenv("EBIRD_API_REGION")

# The number of days to fetch checklists for.
back = int(os.getenv("EBIRD_API_PAST_DAYS"))

# Load the observations from the eBird API.
loader = loaders.APILoader(api_key, settings.API_DATABASE_URL)
loader.load(region, back)
# Out:
# Fetching visits in PT-11
# Number of checklists to fetch: 200
# Fetching checklist S203105907 (2024-11-20)
# Fetching checklist S203105931 (2024-11-20)
# Fetching checklist S203106097 (2024-11-20)
# Fetching checklist S203101583 (2024-11-20)
# Fetching checklist S203104636 (2024-11-20)
# Fetching checklist S203091615 (2024-11-20)
# Fetching checklist S203083793 (2024-11-20)
# Fetching checklist S203086580 (2024-11-20)
# Fetching checklist S203078495 (2024-11-20)
# Fetching checklist S203075721 (2024-11-20)
# Fetching checklist S203071725 (2024-11-20)
# Fetching checklist S203069258 (2024-11-20)
# Fetching checklist S203067873 (2024-11-20)
# Fetching checklist S203066616 (2024-11-20)
# Fetching checklist S203065074 (2024-11-20)
# Fetching checklist S203067108 (2024-11-20)
# Fetching checklist S203024533 (2024-11-19)
# Fetching checklist S203018438 (2024-11-19)
# Fetching checklist S203091482 (2024-11-19)
# Fetching checklist S203024266 (2024-11-19)
# Fetching checklist S203013798 (2024-11-19)
# Fetching checklist S203014550 (2024-11-19)
# Fetching checklist S203037957 (2024-11-19)
# Fetching checklist S203009416 (2024-11-19)
# Fetching checklist S203007810 (2024-11-19)
# Fetching checklist S203006523 (2024-11-19)
# Fetching checklist S203006724 (2024-11-19)
# Fetching checklist S203005057 (2024-11-19)
# Fetching checklist S203005336 (2024-11-19)
# Fetching checklist S203013170 (2024-11-19)
# Fetching checklist S203020599 (2024-11-19)
# Fetching checklist S203002982 (2024-11-19)
# Fetching checklist S203001853 (2024-11-19)
# Fetching checklist S203001338 (2024-11-19)
# Fetching checklist S203021857 (2024-11-19)
# Fetching checklist S203001642 (2024-11-19)
# Fetching checklist S203001643 (2024-11-19)
# Fetching checklist S202999652 (2024-11-19)
# Fetching checklist S202998605 (2024-11-19)
# Fetching checklist S203021880 (2024-11-19)
# Fetching checklist S203017085 (2024-11-19)
# Fetching checklist S203021909 (2024-11-19)
# Fetching checklist S203023758 (2024-11-19)
# Fetching checklist S203021939 (2024-11-19)
# Fetching checklist S202994744 (2024-11-19)
# Fetching checklist S203021979 (2024-11-19)
# Fetching checklist S203022017 (2024-11-19)
# Fetching checklist S202992799 (2024-11-19)
# Fetching checklist S203023254 (2024-11-19)
# Fetching checklist S203013281 (2024-11-19)
# Fetching checklist S203018957 (2024-11-19)
# Fetching checklist S203022044 (2024-11-19)
# Fetching checklist S202987922 (2024-11-19)
# Fetching checklist S202985218 (2024-11-19)
# Fetching checklist S203022065 (2024-11-19)
# Fetching checklist S203065080 (2024-11-19)
# Fetching checklist S203097250 (2024-11-19)
# Fetching checklist S202987326 (2024-11-19)
# Fetching checklist S202981910 (2024-11-19)
# Fetching checklist S202984633 (2024-11-19)
# Fetching checklist S202981395 (2024-11-19)
# Fetching checklist S202982372 (2024-11-19)
# Fetching checklist S202987241 (2024-11-19)
# Fetching checklist S202980566 (2024-11-19)
# Fetching checklist S203013619 (2024-11-19)
# Fetching checklist S202980872 (2024-11-19)
# Fetching checklist S202998618 (2024-11-19)
# Fetching checklist S202983722 (2024-11-18)
# Fetching checklist S202939813 (2024-11-18)
# Fetching checklist S202938784 (2024-11-18)
# Fetching checklist S202934705 (2024-11-18)
# Fetching checklist S202932095 (2024-11-18)
# Fetching checklist S202962017 (2024-11-18)
# Fetching checklist S202930712 (2024-11-18)
# Fetching checklist S202954429 (2024-11-18)
# Fetching checklist S202916161 (2024-11-18)
# Fetching checklist S202916162 (2024-11-18)
# Fetching checklist S202940270 (2024-11-18)
# Fetching checklist S202926238 (2024-11-18)
# Fetching checklist S202909645 (2024-11-18)
# Fetching checklist S202908066 (2024-11-18)
# Fetching checklist S202907646 (2024-11-18)
# Fetching checklist S203028031 (2024-11-18)
# Fetching checklist S202905723 (2024-11-18)
# Fetching checklist S202930428 (2024-11-18)
# Fetching checklist S202907396 (2024-11-18)
# Fetching checklist S202899692 (2024-11-18)
# Fetching checklist S202896431 (2024-11-18)
# Fetching checklist S202894729 (2024-11-18)
# Fetching checklist S202930248 (2024-11-18)
# Fetching checklist S202890885 (2024-11-18)
# Fetching checklist S202896465 (2024-11-18)
# Fetching checklist S202899242 (2024-11-18)
# Fetching checklist S202887667 (2024-11-18)
# Fetching checklist S202892971 (2024-11-18)
# Fetching checklist S202926984 (2024-11-18)
# Fetching checklist S202886316 (2024-11-18)
# Fetching checklist S202884730 (2024-11-18)
# Fetching checklist S202885980 (2024-11-18)
# Fetching checklist S202886449 (2024-11-18)
# Fetching checklist S202961763 (2024-11-18)
# Fetching checklist S202883126 (2024-11-18)
# Fetching checklist S202961745 (2024-11-18)
# Fetching checklist S202961713 (2024-11-18)
# Fetching checklist S202882180 (2024-11-18)
# Fetching checklist S202961677 (2024-11-18)
# Fetching checklist S202889944 (2024-11-18)
# Fetching checklist S202881970 (2024-11-18)
# Fetching checklist S202884355 (2024-11-18)
# Fetching checklist S202884354 (2024-11-18)
# Fetching checklist S202880744 (2024-11-18)
# Fetching checklist S202880140 (2024-11-18)
# Fetching checklist S202882105 (2024-11-18)
# Fetching checklist S202879575 (2024-11-18)
# Fetching checklist S202948829 (2024-11-18)
# Fetching checklist S202858360 (2024-11-17)
# Fetching checklist S202880152 (2024-11-17)
# Fetching checklist S202850113 (2024-11-17)
# Fetching checklist S202845533 (2024-11-17)
# Fetching checklist S202845532 (2024-11-17)
# Fetching checklist S202812672 (2024-11-17)
# Fetching checklist S202813992 (2024-11-17)
# Fetching checklist S202813993 (2024-11-17)
# Fetching checklist S202816851 (2024-11-17)
# Fetching checklist S202811575 (2024-11-17)
# Fetching checklist S202817525 (2024-11-17)
# Fetching checklist S203001714 (2024-11-17)
# Fetching checklist S202810199 (2024-11-17)
# Fetching checklist S202810459 (2024-11-17)
# Fetching checklist S202812873 (2024-11-17)
# Fetching checklist S202804127 (2024-11-17)
# Fetching checklist S202805291 (2024-11-17)
# Fetching checklist S202878409 (2024-11-17)
# Fetching checklist S202803106 (2024-11-17)
# Fetching checklist S202803103 (2024-11-17)
# Fetching checklist S202810582 (2024-11-17)
# Fetching checklist S202937478 (2024-11-17)
# Fetching checklist S202937461 (2024-11-17)
# Fetching checklist S202797906 (2024-11-17)
# Fetching checklist S202799199 (2024-11-17)
# Fetching checklist S202831816 (2024-11-17)
# Fetching checklist S202831817 (2024-11-17)
# Fetching checklist S202790727 (2024-11-17)
# Fetching checklist S202790725 (2024-11-17)
# Fetching checklist S202815745 (2024-11-17)
# Fetching checklist S202786648 (2024-11-17)
# Fetching checklist S202831915 (2024-11-17)
# Fetching checklist S202831916 (2024-11-17)
# Fetching checklist S202803330 (2024-11-17)
# Fetching checklist S202816713 (2024-11-17)
# Fetching checklist S202805050 (2024-11-17)
# Fetching checklist S202886447 (2024-11-17)
# Fetching checklist S202775305 (2024-11-17)
# Fetching checklist S202774227 (2024-11-17)
# Fetching checklist S202772601 (2024-11-17)
# Fetching checklist S202826632 (2024-11-17)
# Fetching checklist S202826631 (2024-11-17)
# Fetching checklist S202783983 (2024-11-17)
# Fetching checklist S202818944 (2024-11-17)
# Fetching checklist S202758048 (2024-11-17)
# Fetching checklist S202758049 (2024-11-17)
# Fetching checklist S202767103 (2024-11-17)
# Fetching checklist S202766526 (2024-11-17)
# Fetching checklist S202755180 (2024-11-17)
# Fetching checklist S202844474 (2024-11-17)
# Fetching checklist S202818773 (2024-11-17)
# Fetching checklist S202754873 (2024-11-17)
# Fetching checklist S202796634 (2024-11-17)
# Fetching checklist S202793391 (2024-11-17)
# Fetching checklist S202749804 (2024-11-17)
# Fetching checklist S202749805 (2024-11-17)
# Fetching checklist S202750901 (2024-11-17)
# Fetching checklist S202749907 (2024-11-17)
# Fetching checklist S202779276 (2024-11-17)
# Fetching checklist S202795562 (2024-11-17)
# Fetching checklist S202795456 (2024-11-17)
# Fetching checklist S202748385 (2024-11-17)
# Fetching checklist S202760272 (2024-11-17)
# Fetching checklist S202747715 (2024-11-17)
# Fetching checklist S202747754 (2024-11-17)
# Fetching checklist S202745901 (2024-11-17)
# Fetching checklist S202746899 (2024-11-17)
# Fetching checklist S202744178 (2024-11-17)
# Fetching checklist S202752787 (2024-11-17)
# Fetching checklist S202694237 (2024-11-16)
# Fetching checklist S202715211 (2024-11-16)
# Fetching checklist S202678335 (2024-11-16)
# Fetching checklist S202717338 (2024-11-16)
# Fetching checklist S202668612 (2024-11-16)
# Fetching checklist S202669122 (2024-11-16)
# Fetching checklist S202673601 (2024-11-16)
# Fetching checklist S202673600 (2024-11-16)
# Fetching checklist S202742379 (2024-11-16)
# Fetching checklist S202742380 (2024-11-16)
# Fetching checklist S202826685 (2024-11-16)
# Fetching checklist S202663888 (2024-11-16)
# Fetching checklist S202716968 (2024-11-16)
# Fetching checklist S202786755 (2024-11-16)
# Fetching checklist S202658844 (2024-11-16)
# Fetching checklist S202658843 (2024-11-16)
# Successfully loaded API records
# 95 records added
# 0 records updated
# 2193 records unchanged
# 2288 records in total
