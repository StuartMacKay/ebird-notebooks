# %%
"""
Getting Started

This notebook show you how to:

1. Create a database and load observations from cvs file containing
   records from the eBird Basic Dataset v1.14

2. Create a database and load observations from the eBird API v2.0

For your convenience, there is a settings file, "ebird/db/settings.py"
which contains default connection strings used by sqlAlchemy to create
and access the databases in the 'data' directory. You can replace this
will any path you choose.

IMPORTANT: Add the root directory of the project so the code in the
'ebird.db' module can be loaded. You must add this as the first cell
in any notebook you create, which access the databases.
"""
import sys

sys.path.insert(0, "..")

# %%
# Create a database and load eBird Basic Dataset observations.

from sqlalchemy import create_engine
from ebird.db import loaders, models, settings

# Create the sqlite3 database and initialize the tables.
engine = create_engine(settings.EBD_DATABASE_URL)
models.Base.metadata.create_all(engine)
# Load the records from the csv file.
loader = loaders.EBDLoader(settings.EBD_DATABASE_URL)
loader.load("../data/ebd.csv")
# Out:
# Loading eBird Basic Dataset from ../data/ebd.csv
# .......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# Successfully loaded eBird Basic Dataset
# 1399 records added
# 0 records updated
# 0 records unchanged
# 1399 records in total

# %%
# Create a database and load observations using the eBird API.
# The assumption is that the database.

from sqlalchemy import create_engine
from ebird.db import loaders, models, settings

# Create the sqlite3 database and initialize the tables.
engine = create_engine(settings.API_DATABASE_URL)
models.Base.metadata.create_all(engine)

# You will need to sign up for a key to access the eBird API.
# https://ebird.org/api/keygen
api_key = "<my-api-key>"
# The region for which to load observations for. This can be any country,
# subnational1, or subnational2 code.
region = "US-MA"

# Load the observations from the eBird API. 
# The call to the api returns the 200 most recent visits (the maximum 
# allowed). Depending on the number of checklists submitted each day, 
# there will be a trade-off between how often you run the loader and 
# the number of checklists downloaded that are unchanged. Having said
# that, downloading the maximum allowed is the only way to catch  
# checklists which are only submitted a few days after they were made.
loader = loaders.APILoader(api_key, settings.API_DATABASE_URL)
loader.load(region)
# Out:
# Loading eBird taxonomy
# Fetching visits in PT-11
# Number of checklists to fetch: 200
# Fetching checklist S202790727
# Fetching checklist S202790725
# Fetching checklist S202786648
# Fetching checklist S202775305
# Fetching checklist S202774227
# Fetching checklist S202772601
# Fetching checklist S202783983
# Fetching checklist S202758048
# Fetching checklist S202758049
# Fetching checklist S202767103
# Fetching checklist S202766526
# Fetching checklist S202755180
# Fetching checklist S202754873
# Fetching checklist S202749804
# Fetching checklist S202749805
# Fetching checklist S202750901
# Fetching checklist S202749907
# Fetching checklist S202779276
# Fetching checklist S202748385
# Fetching checklist S202760272
# Fetching checklist S202747715
# Fetching checklist S202747754
# Fetching checklist S202745901
# Fetching checklist S202746899
# Fetching checklist S202744178
# Fetching checklist S202752787
# Fetching checklist S202694237
# Fetching checklist S202715211
# Fetching checklist S202678335
# Fetching checklist S202717338
# Fetching checklist S202668612
# Fetching checklist S202669122
# Fetching checklist S202673601
# Fetching checklist S202673600
# Fetching checklist S202742379
# Fetching checklist S202742380
# Fetching checklist S202663888
# Fetching checklist S202716968
# Fetching checklist S202786755
# Fetching checklist S202658844
# Fetching checklist S202658843
# Fetching checklist S202656917
# Fetching checklist S202656561
# Fetching checklist S202655529
# Fetching checklist S202663253
# Fetching checklist S202663251
# Fetching checklist S202655168
# Fetching checklist S202654693
# Fetching checklist S202655842
# Fetching checklist S202653291
# Fetching checklist S202674455
# Fetching checklist S202657089
# Fetching checklist S202646570
# Fetching checklist S202677590
# Fetching checklist S202633148
# Fetching checklist S202633149
# Fetching checklist S202752963
# Fetching checklist S202690470
# Fetching checklist S202643992
# Fetching checklist S202634055
# Fetching checklist S202624575
# Fetching checklist S202624822
# Fetching checklist S202625825
# Fetching checklist S202624514
# Fetching checklist S202624513
# Fetching checklist S202624162
# Fetching checklist S202623441
# Fetching checklist S202677586
# Fetching checklist S202626318
# Fetching checklist S202622157
# Fetching checklist S202716395
# Fetching checklist S202621685
# Fetching checklist S202624639
# Fetching checklist S202621755
# Fetching checklist S202632406
# Fetching checklist S202620013
# Fetching checklist S202715752
# Fetching checklist S202618247
# Fetching checklist S202579620
# Fetching checklist S202580213
# Fetching checklist S202579871
# Fetching checklist S202584798
# Fetching checklist S202584835
# Fetching checklist S202556896
# Fetching checklist S202556895
# Fetching checklist S202556413
# Fetching checklist S202680829
# Fetching checklist S202554543
# Fetching checklist S202556482
# Fetching checklist S202556481
# Fetching checklist S202548575
# Fetching checklist S202548574
# Fetching checklist S202550871
# Fetching checklist S202584634
# Fetching checklist S202545031
# Fetching checklist S202541485
# Fetching checklist S202540833
# Fetching checklist S202558089
# Fetching checklist S202541453
# Fetching checklist S202535728
# Fetching checklist S202534672
# Fetching checklist S202557124
# Fetching checklist S202531862
# Fetching checklist S202529544
# Fetching checklist S202550337
# Fetching checklist S202545703
# Fetching checklist S202524509
# Fetching checklist S202524436
# Fetching checklist S202584668
# Fetching checklist S202523175
# Fetching checklist S202565337
# Fetching checklist S202523038
# Fetching checklist S202524260
# Fetching checklist S202584743
# Fetching checklist S202524259
# Fetching checklist S202584779
# Fetching checklist S202524786
# Fetching checklist S202742400
# Fetching checklist S202524148
# Fetching checklist S202557413
# Fetching checklist S202521257
# Fetching checklist S202520579
# Fetching checklist S202519464
# Fetching checklist S202521341
# Fetching checklist S202521342
# Fetching checklist S202523142
# Fetching checklist S202540871
# Fetching checklist S202499449
# Fetching checklist S202476653
# Fetching checklist S202472900
# Fetching checklist S202528855
# Fetching checklist S202458216
# Fetching checklist S202458235
# Fetching checklist S202499255
# Fetching checklist S202452270
# Fetching checklist S202479508
# Fetching checklist S202451227
# Fetching checklist S202452903
# Fetching checklist S202452902
# Fetching checklist S202463441
# Fetching checklist S202452904
# Fetching checklist S202451015
# Fetching checklist S202476434
# Fetching checklist S202450626
# Fetching checklist S202442579
# Fetching checklist S202446106
# Fetching checklist S202475667
# Fetching checklist S202437978
# Fetching checklist S202436701
# Fetching checklist S202440846
# Fetching checklist S202692494
# Fetching checklist S202698681
# Fetching checklist S202692495
# Fetching checklist S202434984
# Fetching checklist S202433519
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/http/client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/http/client.py:1382, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1381     body = _encode(body, 'body')
# -> 1382 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/http/client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/http/client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/http/client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/http/client.py:1477, in HTTPSConnection.connect(self)
#    1475     server_hostname = self.host
# -> 1477 self.sock = self._context.wrap_socket(self.sock,
#    1478                                       server_hostname=server_hostname)
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/ssl.py:1041, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1040                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041             self.do_handshake()
#    1042 except:
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/ssl.py:1319, in SSLSocket.do_handshake(self, block)
#    1318         self.settimeout(None)
# -> 1319     self._sslobj.do_handshake()
#    1320 finally:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[4], line 20
#      18 # Load the observations from the eBird Basic Dataset.
#      19 loader = loaders.APILoader(api_key, settings.API_DATABASE_URL)
# ---> 20 loader.load(region)
#
# File ~/Development/ebird-notebooks/notebooks/../ebird/db/loaders.py:328, in APILoader.load(self, region)
#     326 for visit in visits:
#     327     sys.stdout.write("Fetching checklist %s\n" % visit["subId"])
# --> 328     checklist = get_checklist(self.api_key, visit["subId"])
#     329     checklist["loc"] = visit["loc"]
#     330     for observation in checklist.pop("obs"):
#
# File ~/Development/ebird-notebooks/.venv/lib/python3.12/site-packages/ebird/api/checklists.py:101, in get_checklist(token, sub_id)
#      95 url = CHECKLIST_URL % clean_code(sub_id)
#      97 headers = {
#      98     "X-eBirdApiToken": token,
#      99 }
# --> 101 return call(url, {}, headers)
#
# File ~/Development/ebird-notebooks/.venv/lib/python3.12/site-packages/ebird/api/utils.py:164, in call(url, params, headers)
#     162 filtered = filter_parameters(params)
#     163 mapped = map_parameters(filtered)
# --> 164 return get_json(get_response(url, mapped, headers))
#
# File ~/Development/ebird-notebooks/.venv/lib/python3.12/site-packages/ebird/api/utils.py:107, in get_response(url, params, headers)
#     104     for name, value in headers.items():
#     105         request.add_header(name, value)
# --> 107 return urlopen(request).read()
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/urllib/request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/urllib/request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/urllib/request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File ~/.local/share/uv/python/cpython-3.12.6-linux-x86_64-gnu/lib/python3.12/urllib/request.py:1347, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1344         h.request(req.get_method(), req.selector, req.data, headers,
#    1345                   encode_chunked=req.has_header('Transfer-encoding'))
#    1346     except OSError as err: # timeout error
# -> 1347         raise URLError(err)
#    1348     r = h.getresponse()
#    1349 except:
#
# URLError: <urlopen error [Errno 104] Connection reset by peer>
